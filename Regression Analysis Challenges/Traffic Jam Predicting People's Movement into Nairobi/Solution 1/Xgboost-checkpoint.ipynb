# %%
import sys  
sys.path.append("../../")
from LIB.utils import *

# %%
v="final"

train_df=pd.read_csv("../features/final_data/train_{}.csv".format(v))
test_df=pd.read_csv("../features/final_data/test_{}.csv".format(v))

# %%
keys= ["ride_id"]
Target_name="number_of_ticket"
not_used_cols=["ride_id","travel_time" ,"travel_date","date","month","week",Target_name,"ratio_number_of_ticket",
                                'Speed_max_capicty',
                                 'count_travel_from',
                                 'is_tommorw_holidays',
                                 'is_yesterday_holidays'
       
]
feautres_name=[ f for f in test_df.columns if f not in not_used_cols]
from sklearn.metrics import mean_absolute_error
def eval_metrics(y_ture,y_hat):
    return mean_absolute_error(y_ture,y_hat)

# %%
len(feautres_name)
# Out:
# 50

# %%
from LIB.xgb import * 
params= {
            'min_child_weight': 10, 
            'eta': 0.004, 
            'colsample_bytree': 0.7, 
            'max_depth': 9,
            'subsample': 0.9, 'lambda': 5, 
            'nthread': 4, 
            'booster' : 'gbtree', 
            'eval_metric': 'rmse', 
            'objective': 'reg:linear',
            "gamma":0.5 ,
            "alpha":0.04,
            'silent': 1
}
XGBoost= Xgboost_model( Train_df=train_df,
                        Test_df=test_df,
                        feval_metrics=eval_metrics,
                        Target_name=Target_name,
                        params=params,
                        feature_names=feautres_name,
                        keys=keys,
                        verbose_eval=100,
                        early_stopping_rounds=100,
                        num_boost_round=20000,
                        maximize=False,
                        test_size=0.1,
                        nbr_fold=10,
                        nbr_run=3)
# Out:
# Shape of Train (6249, 57)
# Shape of Test (1111, 56)

# %%
train_pred_xgboost,test_pred_xgboost=XGBoost.Xgboost_Kfold()
# train_pred_xgboost,test_pred_xgboost=XGBoost.Xgboost_RepeatedKFold()


test_pred_xgboost[Target_name]=test_pred_xgboost[Target_name].apply(lambda x : 1 if x<0 else x ).round()
# Out:
# ##################################################fold:1##################################################
# run 0 train metrics :2.1364639 val metrics : 2.9606998
# run 1 train metrics :2.128008 val metrics : 2.9563663
# run 2 train metrics :2.1758604 val metrics : 2.9740655
#
# fold-1 train metrics :2.1467774 val metrics : 2.9637105
# ##################################################fold:2##################################################
# run 0 train metrics :2.089475 val metrics : 3.0877216
# run 1 train metrics :1.8829399 val metrics : 3.0968933
# run 2 train metrics :1.8486004 val metrics : 3.0973132
#
# fold-2 train metrics :1.9403385 val metrics : 3.093976
# ##################################################fold:3##################################################
# run 0 train metrics :2.0929892 val metrics : 2.9061887
# run 1 train metrics :2.1317666 val metrics : 2.8955328
# run 2 train metrics :2.0580695 val metrics : 2.8948483
#
# fold-3 train metrics :2.0942752 val metrics : 2.8988564
# ##################################################fold:4##################################################
# run 0 train metrics :1.9813251 val metrics : 2.8503284
# run 1 train metrics :1.954494 val metrics : 2.8666692
# run 2 train metrics :2.0070019 val metrics : 2.8666327
#
# fold-4 train metrics :1.9809403 val metrics : 2.86121
# ##################################################fold:5##################################################
# run 0 train metrics :2.189153 val metrics : 2.8556223
# run 1 train metrics :2.261913 val metrics : 2.8670013
# run 2 train metrics :2.228863 val metrics : 2.8637247
#
# fold-5 train metrics :2.2266428 val metrics : 2.862116
# ##################################################fold:6##################################################
# run 0 train metrics :2.1686077 val metrics : 2.9478128
# run 1 train metrics :2.1564052 val metrics : 2.9524317
# run 2 train metrics :2.0822957 val metrics : 2.9439442
#
# fold-6 train metrics :2.1357696 val metrics : 2.948063
# ##################################################fold:7##################################################
# run 0 train metrics :2.0721848 val metrics : 3.1020238
# run 1 train metrics :2.0888617 val metrics : 3.112823
# run 2 train metrics :2.1179802 val metrics : 3.107176
#
# fold-7 train metrics :2.093009 val metrics : 3.1073408
# ##################################################fold:8##################################################
# run 0 train metrics :1.9914843 val metrics : 3.022615
# run 1 train metrics :1.9618995 val metrics : 3.018127
# run 2 train metrics :1.9966112 val metrics : 3.020084
#
# fold-8 train metrics :1.9833317 val metrics : 3.020275
# ##################################################fold:9##################################################
# run 0 train metrics :1.9522371 val metrics : 3.0909903
# run 1 train metrics :1.9980948 val metrics : 3.0855205
# run 2 train metrics :1.9753904 val metrics : 3.0808485
#
# fold-9 train metrics :1.9752407 val metrics : 3.0857866
# ##################################################fold:10##################################################
# run 0 train metrics :2.142635 val metrics : 2.8504884
# run 1 train metrics :2.1639493 val metrics : 2.852262
# run 2 train metrics :2.1378236 val metrics : 2.8544269
#
# fold-10 train metrics :2.148136 val metrics : 2.8523922
# End Training with  train metrics :2.072446 val metrics : 2.9693725

# %%
train_pred_xgboost[Target_name+"pred"]=train_pred_xgboost[Target_name+"pred"].apply(lambda x : 1 if x<0 else x ).round()
train_pred_xgboost=train_pred_xgboost.merge(train_df[["ride_id","date"]],how="left",on="ride_id")
train_pred_xgboost.date=pd.to_datetime(train_pred_xgboost.date)
Train=train_pred_xgboost[~train_pred_xgboost.date.between(datetime(2018,4,3),datetime(2018,4,20))]
Val=train_pred_xgboost[train_pred_xgboost.date.between(datetime(2018,4,3),datetime(2018,4,20))]
print( "Train")
print(mean_absolute_error(Train.number_of_ticket, Train.number_of_ticketpred))
print("Val : ")
print(mean_absolute_error(Val.number_of_ticket, Val.number_of_ticketpred))
# Out:
# Train
# 2.9531505356818593
# Val :
# 3.0026954177897576

# %%
test_pred_xgboost.number_of_ticket=test_pred_xgboost.number_of_ticket.round()
test_pred_xgboost.to_csv("../sub/Xboost_sub.csv",index=False)

# %%
XGBoost.plot_importance()
